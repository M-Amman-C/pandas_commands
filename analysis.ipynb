# %% [markdown]
# # Census Income
# Predict whether income exceeds $50K/yr based on census data.

# %% [markdown]
# **Getting Started**

# %%
pip install pandas #install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#importing pandas
import pandas as pd

#importing data from csv
df = pd.read_csv("Data.csv") #https://archive.ics.uci.edu/dataset/20/census+income

# %% [markdown]
# **Displaying Output**

# %%
df.head(10) #Show first five rows
# Out:
#    age          workclass   fnlwgt   education   education-num  \
# 0   39          State-gov    77516   Bachelors              13
# 1   50   Self-emp-not-inc    83311   Bachelors              13
# 2   38            Private   215646     HS-grad               9
# 3   53            Private   234721        11th               7
# 4   28            Private   338409   Bachelors              13
# 5   37            Private   284582     Masters              14
# 6   49            Private   160187         9th               5
# 7   52   Self-emp-not-inc   209642     HS-grad               9
# 8   31            Private    45781     Masters              14
# 9   42            Private   159449   Bachelors              13
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df.tail(10) #Show last five rows
# Out:
#        age      workclass   fnlwgt      education   education-num  \
# 32551   32        Private    34066           10th               6
# 32552   43        Private    84661      Assoc-voc              11
# 32553   32        Private   116138        Masters              14
# 32554   53        Private   321865        Masters              14
# 32555   22        Private   310152   Some-college              10
# 32556   27        Private   257302     Assoc-acdm              12
# 32557   40        Private   154374        HS-grad               9
# 32558   58        Private   151910        HS-grad               9
# 32559   22        Private   201490        HS-grad               9
# 32560   52   Self-emp-inc   287927        HS-grad               9
#
#             marital-status          occupation    relationship  \
# 32551   Married-civ-spouse   Handlers-cleaners         Husband
# 32552   Married-civ-spouse               Sales         Husband
# ...

# %% [markdown]
# **Understanding data**

# %%
df.info() #getting information on data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              32561 non-null  int64
#  1    workclass       32561 non-null  object
#  2    fnlwgt          32561 non-null  int64
#  3    education       32561 non-null  object
#  4    education-num   32561 non-null  int64
#  5    marital-status  32561 non-null  object
#  6    occupation      32561 non-null  object
#  7    relationship    32561 non-null  object
#  8    race            32561 non-null  object
#  9    sex             32561 non-null  object
#  10   capital-gain    32561 non-null  int64
#  11   capital-loss    32561 non-null  int64
#  12   hours-per-week  32561 non-null  int64
#  13   native-country  32561 non-null  object
#  14   income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.shape #getting rows and columns
# Out:
# (32561, 15)

# %%
df.describe() #statisttics on data columns
# Out:
#                 age        fnlwgt   education-num   capital-gain  \
# count  32561.000000  3.256100e+04    32561.000000   32561.000000
# mean      38.581647  1.897784e+05       10.080679    1077.648844
# std       13.640433  1.055500e+05        2.572720    7385.292085
# min       17.000000  1.228500e+04        1.000000       0.000000
# 25%       28.000000  1.178270e+05        9.000000       0.000000
# 50%       37.000000  1.783560e+05       10.000000       0.000000
# 75%       48.000000  2.370510e+05       12.000000       0.000000
# max       90.000000  1.484705e+06       16.000000   99999.000000
#
#         capital-loss   hours-per-week
# count   32561.000000     32561.000000
# mean       87.303830        40.437456
# std       402.960219        12.347429
# min         0.000000         1.000000
# 25%         0.000000        40.000000
# 50%         0.000000        40.000000
# 75%         0.000000        45.000000
# max      4356.000000        99.000000

# %% [markdown]
# **Column names**

# %%
df.columns #getting column names
# Out:
# Index(['age', ' workclass', ' fnlwgt', ' education', ' education-num',
#        ' marital-status', ' occupation', ' relationship', ' race', ' sex',
#        ' capital-gain', ' capital-loss', ' hours-per-week', ' native-country',
#        ' income'],
#       dtype='object')

# %%
df.columns.to_list() #getting column names as list
# Out:
# ['age',
#  ' workclass',
#  ' fnlwgt',
#  ' education',
#  ' education-num',
#  ' marital-status',
#  ' occupation',
#  ' relationship',
#  ' race',
#  ' sex',
#  ' capital-gain',
#  ' capital-loss',
#  ' hours-per-week',
#  ' native-country',
#  ' income']

# %% [markdown]
# **Checking missing values**

# %%
df2 = df.copy()
df2.loc[2:4,' capital-gain'] = None
df2.head(7)
# Out:
#    age          workclass   fnlwgt   education   education-num  \
# 0   39          State-gov    77516   Bachelors              13
# 1   50   Self-emp-not-inc    83311   Bachelors              13
# 2   38            Private   215646     HS-grad               9
# 3   53            Private   234721        11th               7
# 4   28            Private   338409   Bachelors              13
# 5   37            Private   284582     Masters              14
# 6   49            Private   160187         9th               5
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# 3      Married-civ-spouse   Handlers-cleaners         Husband   Black
# 4      Married-civ-spouse      Prof-specialty            Wife   Black
# ...

# %%
df2.isnull().head(7) #checking for NULL values
# Out:
#      age   workclass   fnlwgt   education   education-num   marital-status  \
# 0  False       False    False       False           False            False
# 1  False       False    False       False           False            False
# 2  False       False    False       False           False            False
# 3  False       False    False       False           False            False
# 4  False       False    False       False           False            False
# 5  False       False    False       False           False            False
# 6  False       False    False       False           False            False
#
#     occupation   relationship   race    sex   capital-gain   capital-loss  \
# 0        False          False  False  False          False          False
# 1        False          False  False  False          False          False
# 2        False          False  False  False           True          False
# ...

# %%
df2.isnull().sum() #counting total NULL values by column
# Out:
# age                0
#  workclass         0
#  fnlwgt            0
#  education         0
#  education-num     0
#  marital-status    0
#  occupation        0
#  relationship      0
#  race              0
#  sex               0
#  capital-gain      3
#  capital-loss      0
#  hours-per-week    0
#  native-country    0
#  income            0
# dtype: int64

# %%
df2.isnull().sum().sum() #counting total NULL values in data
# Out:
# 3

# %% [markdown]
# **Slicing and Extracting Data**

# %%
df['income']
# Out:
# 0         <=50K
# 1         <=50K
# 2         <=50K
# 3         <=50K
# 4         <=50K
#           ...
# 32556     <=50K
# 32557      >50K
# 32558     <=50K
# 32559     <=50K
# 32560      >50K
# Name: income, Length: 32561, dtype: object

# %%
df[df.index==190] #Getting a single row of data
# Out:
#      age  workclass   fnlwgt      education   education-num  marital-status  \
# 190   38    Private   155222   Some-college              10        Divorced
#
#              occupation    relationship    race      sex   capital-gain  \
# 190   Machine-op-inspct   Not-in-family   Black   Female              0
#
#       capital-loss   hours-per-week  native-country  income
# 190              0               28   United-States   <=50K

# %%
df[df.index.isin(range(101,111))] #Getting many single row of data
# Out:
#      age          workclass   fnlwgt      education   education-num  \
# 101   44            Private   198282      Bachelors              13
# 102   47   Self-emp-not-inc   149116        Masters              14
# 103   20            Private   188300   Some-college              10
# 104   29            Private   103432        HS-grad               9
# 105   32       Self-emp-inc   317660        HS-grad               9
# 106   17                  ?   304873           10th               6
# 107   30            Private   194901           11th               7
# 108   31          Local-gov   189265        HS-grad               9
# 109   42            Private   124692        HS-grad               9
# 110   24            Private   432376      Bachelors              13
#
#           marital-status          occupation     relationship    race  \
# 101   Married-civ-spouse     Exec-managerial          Husband   White
# 102        Never-married      Prof-specialty    Not-in-family   White
# ...

# %% [markdown]
# **loc and iloc**

# %%
df2 = df.copy()
df2.loc[1]
# Out:
# age                                50
# workclass            Self-emp-not-inc
# fnlwgt                          83311
# education                   Bachelors
# education-num                      13
# marital-status     Married-civ-spouse
# occupation            Exec-managerial
# relationship                  Husband
# race                            White
# sex                              Male
# capital-gain                        0
# capital-loss                        0
# hours-per-week                     13
# native-country          United-States
# income                          <=50K
# Name: 1, dtype: object

# %%
df2.loc[91:100] #Get multiple rows
# Out:
#      age          workclass   fnlwgt      education   education-num  \
# 91    37            Private   286730   Some-college              10
# 92    28            Private   212563   Some-college              10
# 93    30            Private   117747        HS-grad               9
# 94    34          Local-gov   226296      Bachelors              13
# 95    29          Local-gov   115585   Some-college              10
# 96    48   Self-emp-not-inc   191277      Doctorate              16
# 97    37            Private   202683   Some-college              10
# 98    48            Private   171095     Assoc-acdm              12
# 99    32        Federal-gov   249409        HS-grad               9
# 100   76            Private   124191        Masters              14
#
#           marital-status          occupation    relationship  \
# 91              Divorced        Craft-repair       Unmarried
# 92              Divorced   Machine-op-inspct       Unmarried
# ...

# %%
df2.iloc[100:110, :3] #specifying number of columns
# Out:
#      age          workclass   fnlwgt
# 100   76            Private   124191
# 101   44            Private   198282
# 102   47   Self-emp-not-inc   149116
# 103   20            Private   188300
# 104   29            Private   103432
# 105   32       Self-emp-inc   317660
# 106   17                  ?   304873
# 107   30            Private   194901
# 108   31          Local-gov   189265
# 109   42            Private   124692

# %%
df2.loc[100:110, ['age','education','income']] #specifying exact columns
# Out:
#      age      education  income
# 100   76        Masters    >50K
# 101   44      Bachelors    >50K
# 102   47        Masters   <=50K
# 103   20   Some-college   <=50K
# 104   29        HS-grad   <=50K
# 105   32        HS-grad    >50K
# 106   17           10th   <=50K
# 107   30           11th   <=50K
# 108   31        HS-grad   <=50K
# 109   42        HS-grad   <=50K
# 110   24      Bachelors   <=50K

# %%
df2.loc[df['age']==76, ['age']] = 80 #Modyfying data
df2.loc[100:110, ['age','education','income']] #specifying exact columns
# Out:
#      age      education  income
# 100   80        Masters    >50K
# 101   44      Bachelors    >50K
# 102   47        Masters   <=50K
# 103   20   Some-college   <=50K
# 104   29        HS-grad   <=50K
# 105   32        HS-grad    >50K
# 106   17           10th   <=50K
# 107   30           11th   <=50K
# 108   31        HS-grad   <=50K
# 109   42        HS-grad   <=50K
# 110   24      Bachelors   <=50K

# %%
df2[df['age']>35] #conditional slicing of data
# Out:
#        age          workclass  fnlwgt   education  education-num  \
# 0       39          State-gov   77516   Bachelors             13
# 1       50   Self-emp-not-inc   83311   Bachelors             13
# 2       38            Private  215646     HS-grad              9
# 3       53            Private  234721        11th              7
# 5       37            Private  284582     Masters             14
# ...    ...                ...     ...         ...            ...
# 32552   43            Private   84661   Assoc-voc             11
# 32554   53            Private  321865     Masters             14
# 32557   40            Private  154374     HS-grad              9
# 32558   58            Private  151910     HS-grad              9
# 32560   52       Self-emp-inc  287927     HS-grad              9
#
#             marital-status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# **Cleaning data**

# %%
df2.loc[2:5, 'capital-gain'] = None
df2.loc[5:10, 'capital-loss'] = None
df2.head(10)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %%
df3 = df2.copy()
df3 = df3.dropna() #Drop all NULL rows
df3.shape
# Out:
# (32552, 15)

# %%
df3 = df2.copy()
mean = df3['capital-gain'].mean()
df3 = df3.fillna(mean)
df3.head(10)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %% [markdown]
# **Data Analysis**

# %%
df['age'].mean() #getting mean of column
# Out:
# 38.58164675532078

# %%
df['age'].mode() #getting mode of column
# Out:
# 0    36
# Name: age, dtype: int64

# %%
df['age'].median() #getting median of column
# Out:
# 37.0

# %% [markdown]
# **Creating new columns**

# %%
df2 = df.copy()
df2['diff_in_capital'] = df2['capital-gain']-df2['capital-loss'] #create new column from existing columns
df2[['age','capital-gain','capital-loss','diff_in_capital']].head(10)
# Out:
#    age  capital-gain  capital-loss  diff_in_capital
# 0   39          2174             0             2174
# 1   50             0             0                0
# 2   38             0             0                0
# 3   53             0             0                0
# 4   28             0             0                0
# 5   37             0             0                0
# 6   49             0             0                0
# 7   52             0             0                0
# 8   31         14084             0            14084
# 9   42          5178             0             5178

# %%
df['sex'].value_counts() #getting counts of each value
# Out:
# sex
#  Male      21790
#  Female    10771
# Name: count, dtype: int64

# %%
df.groupby('income').sum() #grouping data by values
# Out:
#            age                                          workclass      fnlwgt  \
# income
#  <=50K  909294   State-gov Self-emp-not-inc Private Private Pr...  4705226187
#  >50K   346963   Self-emp-not-inc Private Private Private Stat...  1474147205
#
#                                                 education  education-num  \
# income
#  <=50K   Bachelors Bachelors HS-grad 11th Bachelors Ma...         237190
#  >50K    HS-grad Masters Bachelors Some-college Bachel...          91047
#
#                                            marital-status  \
# income
#  <=50K   Never-married Married-civ-spouse Divorced Mar...
#  >50K    Married-civ-spouse Never-married Married-civ-...
#
#                                                occupation  \
# income
#  <=50K   Adm-clerical Exec-managerial Handlers-cleaner...
#  >50K    Exec-managerial Prof-specialty Exec-manageria...
#
#                                              relationship  \
# income
# ...

# %% [markdown]
# **Data visualization in pandas**

# %%
df[['age','income']].plot.line()
# Out:
# <Axes: >

# %%
df.plot.line(subplots=True)
# Out:
# array([<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#       dtype=object)

# %%
df['sex'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='sex'>
